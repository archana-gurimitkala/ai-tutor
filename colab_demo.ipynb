# %% [markdown]
# <a href="https://colab.research.google.com/github/archana-gurimitkala/ai-tutor/blob/main/colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/archana-gurimitkala/ai-tutor/blob/main/colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # AI Tutor (Colab Demo)
#
# This notebook lets anyone try your AI Q&A tutor in the browser.
#
# - Uses OpenAI API (user pastes their key once in the session)
# - Asks questions about AI and gets concise answers
# - Type `exit` to end the chat

# %%
# %%capture
# !pip -q install openai>=1.50.0

# %%
import os
from getpass import getpass
from openai import OpenAI

# Prompt user for API key (kept secret in Colab UI)
api_key = getpass("Enter your OpenAI API key: ")
os.environ["OPENAI_API_KEY"] = api_key.strip()

client = OpenAI()

QA_SYSTEM = (
    "You are a patient AI tutor explaining AI/ML concepts to beginners. "
    "Answer the question clearly with simple language, short paragraphs, "
    "and one concrete example. Keep the answer concise."
)

def ask_ai(question: str) -> str:
    resp = client.chat.completions.create(
        model=os.getenv("OPENAI_MODEL", "gpt-4o-mini"),
        messages=[
            {"role": "system", "content": QA_SYSTEM},
            {"role": "user", "content": question},
        ],
    )
    return resp.choices[0].message.content

print("Setup complete. Ask AI questions in the next cell.")
# Out:
# Enter your OpenAI API key: ··········
# Setup complete. Ask AI questions in the next cell.

# %%
print("Type your AI questions (type 'exit' to stop):")
while True:
    q = input("\nYou: ").strip()
    if not q or q.lower() in {"exit", "quit"}:
        print("Goodbye!")
        break
    a = ask_ai(q)
    print("\nTutor:")
    print(a)
# Out:
# Type your AI questions (type 'exit' to stop):
#
# You: what is context window
#
# Tutor:
# A context window in AI and machine learning, especially in natural language processing (NLP), refers to the amount of text or data that a model looks at to understand the meaning of a word or phrase.
#
# For example, if a model is trying to understand the word "bank" in a sentence, the context window would include the surrounding words in that sentence. If the context window is set to 2, the model might consider the two words before and after "bank." This helps the model determine whether "bank" refers to a financial institution or the side of a river based on the other words around it.
#
# Understanding the context helps the model make better predictions or decisions regarding the text it processes.
#
# You: what are parameters?
#
# Tutor:
# In the context of AI and machine learning, parameters are values that the model learns from data during the training process. They help the model understand and make predictions.
#
# Think of parameters like the settings on a music equalizer. Just like you adjust the bass, treble, and volume to get the music just right, in machine learning, parameters are adjusted to improve the model's performance on tasks like predictions or classifications.
#
# For example, in a model predicting house prices, parameters could include the influence of factors like the number of bedrooms, location, and size of the house. The model learns the best values for these parameters from the training data to make accurate predictions.
#
# You: exit
# Goodbye!
